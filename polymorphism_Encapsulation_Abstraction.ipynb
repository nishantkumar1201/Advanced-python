# %%
class person:
    def __init__(self,name,age):
           self.name=name # public variables
           self.age=age # public variables
person=person('Hari',25)

# %%
print(person.name)
# Out:
# Hari

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class person:
    def __init__(self,name,age,gender):
           self.name=name # public variables
           self.age=age # public variables
           self.__gender=gender

# %%
person=person('Hari',25,'Male')
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_person__gender',
#  'age',
#  'name']

# %%
def get_name(person):
    return person.__name

# %%
class person:
  def __init__(self,name,age,gender):
          self._name=name #protected variables can be used in derived class:
          self._age=age   #protected variables can be used in derived class:
          self._gender=gender

class employee(person):
         def __init__(self,name,age,gender):
            super().__init__(name,age,gender)

# %%
class shape:
   def area(self,radius):
     return 3.14*radius*radius
   def area(self,l,b):
     return l*b
s=shape()
s.area(2)
s.area(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a0bb30bea88d> in <cell line: 0>()
#       5      return l*b
#       6 s=shape()
# ----> 7 s.area(2)
#       8 s.area(3,4)
#
# TypeError: shape.area() missing 1 required positional argument: 'b'

# %%
class shape:
   def area(self,a,b=0):
    if b==0:
     return 3.14*a*a
    else:
     return a*b
s=shape()
print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12
