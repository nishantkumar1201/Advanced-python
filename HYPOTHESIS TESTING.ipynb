# %%
# SHAPIRO WILL TEST
# H0= DATA IS NORMALLY DISTRIBUTED
# Ha and H1 = DATA WILL NOT NORMALLY DISTRIBUTED

# %%
from scipy.stats import shapiro

# %%
data=[1.2,1.4,1.6,1.8,2.0,2.2,2.4,2.6,2.8,3.0]
stat,p=shapiro(data)
print(" test stat is:",stat)
print("p value is:",p)
# Out:
#  test stat is: 0.9701646110856056
# p value is: 0.8923673061902975

# %%
if p>0.05:
    print("data is normally distributed")
else:
    print("data is not normally distributed")
# Out:
# data is normally distributed

# %%
pp= shapiro(data)[1]

# %%
pp
# Out:
# 0.8923673061902975

# %%
df=[9320.,4343,34234,42]

# %%
#the D AGOSTINO AND PEARSON K SQUARE test

# %%
from scipy.stats import normaltest

# %%
data=[1.2,1.4,1.6,1.8,2.0,2.2,2.4,2.6,2.8,3.0]
stat1,p1=normaltest(data) # K SQUARE TEST HAMESHA 8 ENTRIES PE LGTA HAI MATLAB MINIMUM 8 HONE CHAHIYE US SE KAM NHI LGEGA
print("test stat is:",stat1)
print("p value is:",p1)
# Out:
# test stat is: 0.9782490674104405
# p value is: 0.6131629627834079
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import numpy as np
from scipy.stats import pearsonr

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
corr,_=pearsonr(x,y)
print("correlation coefficient is:",corr)
# Out:
# correlation coefficient is: 1.0

# %%
r,p=pearsonr(x,y)
print('PERARSON CORELATION TEST:')
print('correlation coefficient is:',r)
print('p value is:',p)
# Out:
# PERARSON CORELATION TEST:
# correlation coefficient is: 1.0
# p value is: 0.0

# %%
r
# Out:
# 1.0

# %%
p # Ha will be accepted because it's values is less than0.5 if it is greater than h0 is accepted
# Out:
# 0.0

# %%
from scipy.stats import spearmanr

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
rho,p=spearmanr(x,y)
print('spearman correlation test:')
print('correlation coefficient is:',rho)
print('p value is:',p)
# Out:
# spearman correlation test:
# correlation coefficient is: 0.9999999999999999
# p value is: 1.4042654220543672e-24
