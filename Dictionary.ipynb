# %%
car_dict={"brand":"BMW","model":"iX","year":1964}
print(car_dict)
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 1964}

# %% [markdown]
# **Dictionaries are used to store data values in key:value pairs.**
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %%
#Accessing Dictionary elements
print(car_dict['brand'])
# Out:
# BMW

# %%
# Length of Dictionary
print(len(car_dict))
# Out:
# 3

# %%
# Type of Data
print(type(car_dict))
# Out:
# <class 'dict'>

# %%
# For Duplicate keys
car_dict2={"brand":"BMW","model":"iX","year":1964,"year":2000}

# %%
car_dict2
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2000}

# %%
car_dict3={"brand":"BMW","model":"iX","year":2024,"year":2000}

# %%
car_dict3
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2000}

# %%
# For Accessing Dict items
x=car_dict.get("model")

# %%
x
# Out:
# 'IIM'

# %%
car_dict.update({"model":"IIM"})
x=car_dict.get("model")
x
# Out:
# 'IIM'

# %%
#The keys() method will return a list of all the keys in the dictionary.
car_dict.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
#The values() method will return a list of all the values in the dictionary.

car_dict.values()
# Out:
# dict_values(['BMW', 'iX', 1964])

# %%
# To change vlaues of Dictionary
car_dict["year"]=2024

# %%
car_dict
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2024}

# %%
# To add new key:value in dictionary
car_dict["color"]="White"

# %%
car_dict
# Out:
# {'brand': 'BMW', 'model': 'iX', 'year': 2024, 'color': 'White'}

# %%
#The values in dictionary items can be of any data type
d3={"name":"A",'year':2023,'Pass':True,'Marks':[50,60,70]}

# %%
print(d3)
# Out:
# {'name': 'A', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
d3.update({'year':2024})

# %%
d3['phone_no']=6395301098

# %%
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'Pass': True,
#  'Marks': [50, 60, 70],
#  'phone_no': 6395301098}

# %%
d3.update({'email':'nishantkumar1962@gmail.com'})

# %%
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'Pass': True,
#  'Marks': [50, 60, 70],
#  'phone_no': 6395301098,
#  'email': 'nishantkumar1962@gmail.com'}

# %%
# For Removing Dictionary items
#The pop() method removes the item with the specified key name:

d3.pop('phone_no')
# Out:
# 6395301098

# %%
d3
# Out:
# {'name': 'A',
#  'year': 2024,
#  'Pass': True,
#  'Marks': [50, 60, 70],
#  'email': 'nishantkumar1962@gmail.com'}

# %%
#The popitem() method removes the last inserted item
d3.popitem()
# Out:
# ('email', 'nishantkumar1962@gmail.com')

# %%
d3
# Out:
# {'name': 'A', 'year': 2024, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
#The del keyword removes the item with the specified key name:

del d3['Marks']

# %%
d3
# Out:
# {'name': 'A', 'year': 2024, 'Pass': True}

# %%
#The del keyword can also delete the dictionary completely:
del d3

# %%
#The clear() method empties the dictionary:
d3.clear()

# %%
d3
# Out:
# {}

# %%
# Copy Dictionary
d3={"name":"A",'year':2023,'Pass':True,'Marks':[50,60,70]}

# %%
d3
# Out:
# {'name': 'A', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
d4= d3.copy()

# %%
d4.update({"name":"nishant"})

# %%
d5=dict(d4)

# %%
d5
# Out:
# {'name': 'nishant', 'year': 2023, 'Pass': True, 'Marks': [50, 60, 70]}

# %%
# Nested Dictionaries

# %%
myfamily = {
  "child1" : {
    "name" : "nishant",
    "year" : 2004
  },
  "child2" : {
    "name" : "vaibhav",
    "year" : 2007
  },
  "child3" : {
    "name" : "shivam",
    "year" : 2011
  }
}

# %%
myfamily
# Out:
# {'child1': {'name': 'nishant', 'year': 2004},
#  'child2': {'name': 'vaibhav', 'year': 2007},
#  'child3': {'name': 'shivam', 'year': 2011}}

# %%
myfamily1 = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
myfamily1
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %%
print(myfamily["child2"]["name"])
# Out:
# vaibhav

# %%
print(myfamily["child3"]["name"])
# Out:
# shivam

# %%
print(myfamily["child2"]["year"])
# Out:
# 2007
