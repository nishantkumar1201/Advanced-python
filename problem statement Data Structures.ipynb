# %%
def hcf(a, b):
    while b:
        a, b = b, a % b
    return a

print(hcf(21, 36))
# Out:
# 3

# %%
def hcf(a, b):
    while b:
        a, b = b, a % b
    return a
num1 = 21
num2 = 36
print("HCF:", hcf(num1, num2))
# Out:
# HCF: 3

# %%
# Initialize variables
prev_num = 0

while True:
    num = int(input("Enter a number (-1 to stop): "))

    # Check if user entered -1 to exit
    if num == -1:
        break

    # Calculate the sum of previous and current numbers
    total = prev_num + num
    print(f"Sum of {prev_num} and {num} is")

    # Update previous number for next iteration
    prev_num = num
# Out:
# Sum of 0 and 5 is

# %%
prev_num = 0

while True:
    num = int(input("Enter a number (-1 to stop): "))

    # Check if user entered -1 to exit
    if num == -1:
        print(f"Enter a number (-1 to stop):  {prev_num}")  # Print final sum before exiting
        break

    # Calculate the sum of previous and current numbers
    total = prev_num + num
    print(f"Sum of {prev_num} and {num} is {total}")

    # Update previous number for next iteration
    prev_num = num
