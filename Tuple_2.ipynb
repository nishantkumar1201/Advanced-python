# %%
# for creating single element tuple

t1=('AAFT',)
print(t1)
# Out:
# ('AAFT',)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2=(1,)
print(type(t2))
# Out:
# <class 'tuple'>

# %%
#Changes in Tuple

x=("A","B","C")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
print(y)
print(type(y))
# Out:
# ['A', 'B', 'C']
# <class 'list'>

# %%
y[2]='Z'

# %%
print(y)
# Out:
# ['A', 'B', 'Z']

# %%
x=tuple(y)

# %%
print(x)
# Out:
# ('A', 'B', 'Z')

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
#Changes in Tuple

x=("A","B","C")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x[1]="G"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-fe4b74ed79ca> in <cell line: 1>()
# ----> 1 x[1]="G"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Adding Tuple to Tuple

t3=(1,2,3)
t4=(5,)

# %%
t5=t3+t4

# %%
print(t5)
# Out:
# (1, 2, 3, 5)
