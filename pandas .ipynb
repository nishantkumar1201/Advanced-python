# %%
import pandas as pd

# %%
## creation of
series=(1,2,3,4,5)
series=pd.Series(series)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series2=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(series2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import numpy as np
array1=np.array([1,2,3,4,5])
array1
# Out:
# array([1, 2, 3, 4, 5])

# %%
series2= pd.Series(array1,index=["jan","feb","march","april","may"])
series2
# Out:
# jan      1
# feb      2
# march    3
# april    4
# may      5
# dtype: int64

# %%
## creation of series with dictionary
dict1={"india":"new delhi","UK":"london","USA":"Washington DC"}
dict1
# Out:
# {'india': 'new delhi', 'UK': 'london', 'USA': 'Washington DC'}

# %%
series3=pd.Series(dict1)
series3
# Out:
# india        new delhi
# UK              london
# USA      Washington DC
# dtype: object

# %%
s=pd.Series([10,20,30])
s[0]
# Out:
# 10

# %%
s1=pd.Series(["new delhi","london","washington DC","Paris"],index=["india","UK","USA","france"])
s1
# Out:
# india         new delhi
# UK               london
# USA       washington DC
# france            Paris
# dtype: object

# %%
s1=pd.Series(np.arange(10,20,2))
s1
# Out:
# 0    10
# 1    12
# 2    14
# 3    16
# 4    18
# dtype: int64

# %%
import pandas as pd

# %%
seriesA=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
seriesB=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

# %%
### FOR ADDITION
seriesA+seriesB
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
c=seriesA*seriesB
c
# Out:
# a     1
# b     4
# c     9
# d    16
# e    25
# dtype: int64

# %%
seriesA-seriesB
# Out:
# a    0
# b    0
# c    0
# d    0
# e    0
# dtype: int64

# %%
import numpy as np

# %%
array1=np.array([1,2,3,4,5])
dFrame=pd.DataFrame(array1)
dFrame
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
rs={"nishant":pd.Series([90,91,87],index=["maths","science","hindi"]),
    "amit":pd.Series([90,85,87],index=["maths","science","hindi"]),
    "mithlesh":pd.Series([80,75,96],index=["maths","science","hindi"]),
    "nidhi":pd.Series([98,78,86],index=["maths","science","hindi"])}

# %%
rs=pd.DataFrame(rs)

# %%
rs
# Out:
#          nishant  amit  mithlesh  nidhi
# maths         90    90        80     98
# science       91    85        75     78
# hindi         87    87        96     86

# %%
## operations-adding a new column
rs['vaibhav']=pd.Series([90,85,98],index=["maths","science","hindi"])

# %%
rs=pd.DataFrame(rs)

# %%
rs
# Out:
#          nishant  amit  mithlesh  nidhi  vaibhav
# maths         90    90        80     98       90
# science       91    85        75     78       85
# hindi         87    87        96     86       98

# %%
rs.loc["maths"]=[85,86,87,88,89]

# %%
rs.drop("hindi",axis=0)
# Out:
#          nishant  amit  mithlesh  nidhi  vaibhav
# maths         85    86        87     88       89
# science       91    85        75     78       85

# %%
#### renaming
rs=rs.rename(columns={"nishant":"nishants","amit":"amits","mithlesh":"mithlehs","nidhi":"nidhis","vaibhav":"vaibhavs"})

# %%
rs
# Out:
#          nishants  amits  mithlehs  nidhis  vaibhavs
# maths          85     86        87      88        89
# science        91     85        75      78        85
# hindi          87     87        96      86        98

# %%
rs.loc["hindi"]
# Out:
# nishants    87
# amits       87
# mithlehs    96
# nidhis      86
# vaibhavs    98
# Name: hindi, dtype: int64

# %%
### Double click(oe enter) to edit
dataset= {'cars':["BMW","ROLLS ROYCE","PORSCHE"]}
df=pd.DataFrame(dataset)

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df
# Out:
#           cars
# 0          BMW
# 1  ROLLS ROYCE
# 2      PORSCHE
