# %%
## concatenation
str1="nishant"
str2="kumar"
final_str=str1+str2
print(final_str)
# Out:
# nishantkumar

# %%
str1="nishant"
str2="kumar"
final_str=str1+" " +str2
print(final_str)
# Out:
# nishant kumar

# %%
str1 = "nishant"
len1 = len(str1)  # Ensure `len` has not been overridden
print(len1)

str2 = "kumar"
len2 = len(str2)  # Use the built-in len function
print(len2)

final_str = str1 + str2
print(final_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e84c58510193> in <cell line: 2>()
#       1 str1 = "nishant"
# ----> 2 len1 = len(str1)  # Ensure `len` has not been overridden
#       3 print(len1)
#       4
#       5 str2 = "kumar"
#
# TypeError: 'int' object is not callable

# %%
## indexing
str1 = "nishant"
print(str1[0])
print(str1[1])
# Out:
# n
# i

# %%
str1 ="nishant kumar"
char= str1[1]
print(char)
# Out:
# i

# %%
str1 ="nishant kumar"
char= str1[10]
print(char)
# Out:
# m

# %%
str ="nishant kumar"
print (str[5])
# Out:
# n

# %%
print(str[7])

# %%
print(str[1:6])
# Out:
# ishan

# %%
print(str[1:9])
# Out:
# ishant k

# %%
print(str[0:])
# Out:
# nishant kumar

# %%
print(str[:])
# Out:
# nishant kumar
